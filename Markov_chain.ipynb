# %% [markdown]
# <a href="https://colab.research.google.com/github/sampritich/Airline/blob/master/Markov_chain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import random as rm

# %%
# The statespace
states = ["Pantaloons","ShoppersStop","H&M"]

# Possible sequences of events
transitionName = [["PP","PH","PS"],["SS","SP","SH"],["HH","HP","HS"]]

# Probabilities matrix (transition matrix)
transitionMatrix = [[0.8,0.1,0.1],[0.7,0.2,0.1],[0.6,0.1,0.3]]

# %%
if sum(transitionMatrix[0])+sum(transitionMatrix[1])+sum(transitionMatrix[1]) != 3:
    print("Somewhere, something went wrong. Transition matrix, perhaps?")
else: print("All is gonna be okay, you should move on!! ;)")
# Out:
# All is gonna be okay, you should move on!! ;)

# %%
# A function that implements the Markov model to forecast the state/mood.
def activity_forecast(days):
    # Choose the starting state
    activityToday = "Pantaloons"
    print("Start state: " + activityToday)
    # Shall store the sequence of states taken. So, this only has the starting state for now.
    activityList = [activityToday]
    i = 0
    # To calculate the probability of the activityList
    prob = 1
    while i != days:
        if activityToday == "Pantaloons":
            change = np.random.choice(transitionName[0],replace=True,p=transitionMatrix[0])
            print(change)
            if change == "PP":
                prob = prob * 0.8
                activityList.append("Pantaloons")
                pass
            elif change == "PS":
                prob = prob * 0.1
                activityToday = "ShoppersStop"
                activityList.append("ShoppersStop")
            else:
                prob = prob * 0.1
                activityToday = "H&M"
                activityList.append("H&M")
        elif activityToday == "ShoppersStop":
            change = np.random.choice(transitionName[1],replace=True,p=transitionMatrix[1])
            if change == "SS":
                prob = prob * 0.7
                activityList.append("ShoppersStop")
                pass
            elif change == "SP":
                prob = prob * 0.2
                activityToday = "Pantaloons"
                activityList.append("Pantaloons")
            else:
                prob = prob * 0.1
                activityToday = "H&M"
                activityList.append("H&M")
        elif activityToday == "H&M":
            change = np.random.choice(transitionName[2],replace=True,p=transitionMatrix[2])
            if change == "HH":
                prob = prob * 0.6
                activityList.append("H&M")
                pass
            elif change == "HS":
                prob = prob * 0.3
                activityToday = "ShoppersStop"
                activityList.append("ShoppersStop")
            else:
                prob = prob * 0.1
                activityToday = "Pantaloons"
                activityList.append("Pantaloons")
        i += 1  
    print("Possible states: " + str(activityList))
    print("End state after "+ str(days) + " days: " + activityToday)
    print("Probability of the possible sequence of states: " + str(prob))
    return activityList

# Function that forecasts the possible state for the next 2 days
activity_forecast(1)
# Out:
# Start state: Pantaloons
# PP
# Possible states: ['Pantaloons', 'Pantaloons']
# End state after 1 days: Pantaloons
# Probability of the possible sequence of states: 0.8
# ['Pantaloons', 'Pantaloons']

# %%
# A function that implements the Markov model to forecast the state/mood.
def activity_forecast(days):
    # Choose the starting state
    activityToday = "Pantaloons"
    print("Start state: " + activityToday)
    # Shall store the sequence of states taken. So, this only has the starting state for now.
    activityList = [activityToday]
    i = 0
    # To calculate the probability of the activityList
    prob = 1
    while i != days:
        if activityToday == "Pantaloons":
            change = np.random.choice(transitionName[0],replace=True,p=transitionMatrix[0])
            print(change)
            if change == "PP":
                prob = prob * 0.8
                activityList.append("Pantaloons")
                pass
            elif change == "PS":
                prob = prob * 0.1
                activityToday = "ShoppersStop"
                activityList.append("ShoppersStop")
            else:
                prob = prob * 0.1
                activityToday = "H&M"
                activityList.append("H&M")
        elif activityToday == "ShoppersStop":
            change = np.random.choice(transitionName[1],replace=True,p=transitionMatrix[1])
            if change == "SS":
                prob = prob * 0.7
                activityList.append("ShoppersStop")
                pass
            elif change == "SP":
                prob = prob * 0.2
                activityToday = "Pantaloons"
                activityList.append("Pantaloons")
            else:
                prob = prob * 0.1
                activityToday = "H&M"
                activityList.append("H&M")
        elif activityToday == "H&M":
            change = np.random.choice(transitionName[2],replace=True,p=transitionMatrix[2])
            if change == "HH":
                prob = prob * 0.6
                activityList.append("H&M")
                pass
            elif change == "HS":
                prob = prob * 0.3
                activityToday = "ShoppersStop"
                activityList.append("ShoppersStop")
            else:
                prob = prob * 0.1
                activityToday = "Pantaloons"
                activityList.append("Pantaloons")
        i += 1  
    return activityList

# Function that forecasts the possible state for the next 2 days
activity_forecast(1)
# Out:
# Start state: Pantaloons
# PP
# ['Pantaloons', 'Pantaloons']

# %%
# To save every activityList
list_activity = []
count = 0

# `Range` starts from the first count up until but excluding the last count
for iterations in range(1,10000):
        list_activity.append(activity_forecast(2))

#Check out all the `activityList` we collected    
print(list_activity)

# Iterate through the list to get a count of all activities ending in state:'Run'
for smaller_list in list_activity:
    if(smaller_list[2] == "Pantaloons"):
        count += 1

# Calculate the probability of starting from state:'Sleep' and ending at state:'Run'
percentage = (count/10000) * 100
print("The probability of starting at state:'Pantaloons' and ending at state:'Pantaloons'= " + str(percentage) + "%")
# Out:
# Streaming output truncated to the last 5000 lines.
# PP
# PS
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# PH
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# PS
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PS
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PS
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# PS
# Start state: Pantaloons
# PS
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PH
# Start state: Pantaloons
# PP
# PS
# Start state: Pantaloons
# PS
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# PH
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PS
# Start state: Pantaloons
# PP
# ...

# %%
# To save every activityList
list_activity = []
count = 0

# `Range` starts from the first count up until but excluding the last count
for iterations in range(1,10000):
        list_activity.append(activity_forecast(2))

#Check out all the `activityList` we collected    
print(list_activity)

# Iterate through the list to get a count of all activities ending in state:'Run'
for smaller_list in list_activity:
    if(smaller_list[2] == "H&M"):
        count += 1

# Calculate the probability of starting from state:'Sleep' and ending at state:'Run'
percentage = (count/10000) * 100
print("The probability of starting at state:'Pantaloons' and ending at state:'Pantaloons'= " + str(percentage) + "%")
# Out:
# Streaming output truncated to the last 5000 lines.
# PP
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# PS
# Start state: Pantaloons
# PP
# PH
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PS
# Start state: Pantaloons
# PP
# PS
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PS
# Start state: Pantaloons
# PH
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PS
# Start state: Pantaloons
# PH
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# ...

# %%
# To save every activityList
list_activity = []
count = 0

# `Range` starts from the first count up until but excluding the last count
for iterations in range(1,10000):
        list_activity.append(activity_forecast(2))

#Check out all the `activityList` we collected    
print(list_activity)

# Iterate through the list to get a count of all activities ending in state:'Run'
for smaller_list in list_activity:
    if(smaller_list[2] == "ShoppersStop"):
        count += 1

# Calculate the probability of starting from state:'Sleep' and ending at state:'Run'
percentage = (count/10000) * 100
print("The probability of starting at state:'Pantaloons' and ending at state:'Pantaloons'= " + str(percentage) + "%")
# Out:
# Streaming output truncated to the last 5000 lines.
# PP
# PP
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PH
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PH
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PS
# Start state: Pantaloons
# PH
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PH
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PH
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# PH
# Start state: Pantaloons
# PS
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# PP
# Start state: Pantaloons
# PP
# PH
# ...
